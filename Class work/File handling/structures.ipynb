# %% [markdown]
# Datatypes :
#     1.primitive
#     2.non - primitive

# %% [markdown]
# Types of data:
#     Structured,
#     Semi - strucutred,
#     Unstructured

# %% [markdown]
# Strucuted data : Any data stored in a proper management and schema. {example : Relational database}
# Semi-structured data : Arranged in a manner but not in Schema. {example : JSON}
# Unstructured : All files present in the computer , image , audio , etc
