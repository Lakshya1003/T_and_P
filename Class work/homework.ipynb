# %% [markdown]
# Difference between stack and queue.

# %% [markdown]
# Difference between array and linked list.

# %% [markdown]
# how variable is allocated in memory.

# %% [markdown]
# why is python dynamically typed language.

# %% [markdown]
# explain memory management in python.

# %% [markdown]
# how do you find the duplicate number number on a given integer array.

# %% [markdown]
# what is infix , prefix and postfix in data structure.

# %% [markdown]
# what is inorder , preorder and postorder.

# %% [markdown]
# what are the polish notataions.

# %% [markdown]
# why do we use Big O instead of Big theta(0).

# %% [markdown]
# How do you convert a Queue into the Stack
