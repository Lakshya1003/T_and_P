# %% [markdown]
# Question : Write a program to find the passward ;
# input1 : 12
# input1 : 1212
# input1 : 567
# input1 : 233
# input1 : 8877

# %%
Inputs = [12,1212,567,233,8877]
counter = []
num = None
stable = 0
unstable = 0
for i in Inputs :
  num = Inputs[i]
  container = []
  while(num > 0) :
    container[i] = num%10
    num = num//10
  tempSet = set(container)
  counter1 = []
  for i in tempSet :
    counter1[i] = container.count(i)
