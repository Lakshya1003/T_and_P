# %% [markdown]
# Question : Write a program to find the passward ;<br>
# input1 : 12 <br>
# input1 : 1212<br>
# input1 : 567<br>
# input1 : 233<br>
# input1 : 8877<br>
#
# output : Sum of stable numbers - sum of unstable numbers <br>
#
# stable number = number whos all unique elements have same frequency

# %%
Inputs = [12,1212,567,233,8877]
counter = []
num = None
stable = 0
unstable = 0
for i in Inputs :
  num = Inputs[i]
  container = []
  while(num > 0) :
    container[i] = num%10
    num = num//10
  tempSet = set(container)
  counter1 = []
  for i in tempSet :
    counter1[i] = container.count(i)
